# %%
0:00:10.364786238 [331m38502[00m 0x7efedc016580 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efedc034120, element=(string)rtpsession0, src=(string)recv_rtp_src, time=(guint64)56091, ts=(guint64)10364759339;
0:00:10.364869648 [331m38502[00m 0x7efedc016580 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x3264b40, element=(string)rtpstorage0, src=(string)src, time=(guint64)82243, ts=(guint64)10364841582;
0:00:10.364910443 [331m38502[00m 0x7efedc016580 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efedc01e2b0, element=(string)rtpssrcdemux0, src=(string)src_184612126, time=(guint64)48579, ts=(guint64)10364890161;
0:00:10.365161469 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efec801afc0, element=(string)rtpjitterbuffer0, src=(string)src, time=(guint64)248936, ts=(guint64)10365139097;
0:00:10.365210184 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efec801f060, element=(string)rtpptdemux0, src=(string)src_35, time=(guint64)41973, ts=(guint64)10365181070;
0:00:10.365247443 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x3942f7f0, element=(string)typefind, src=(string)src, time=(guint64)47280, ts=(guint64)10365228350;
0:00:10.365313176 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c7980, element=(string)rtph264depay0, src=(string)src, time=(guint64)66438, ts=(guint64)10365294788;
0:00:10.365435432 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efec00688b0, element=(string)h264parse0, src=(string)src, time=(guint64)119875, ts=(guint64)10365414663;
0:00:10.365472078 [331m38502[00m 0x7efec801b4c0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efedc038fa0, element=(string)capsfilter0, src=(string)src, time=(guint64)40679, ts=(guint64)10365455342;
0:00:10.525830708 [331m38502[00m 0x7efec0010800 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x7efec00ba930, element=(string)nvv4l2decoder0, src=(string)src, time=(guint64)160311492, ts=(guint64)10525766834;
0:00:10.526025987 [331m38502[00m 0x7efec0010360 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22340a0, element=(string)Stream-muxer, src=(string)src, time=(guint64)209315, ts=(guint64)10525976149;
0:00:10.633493485 [331m38502[00m      0x3407c00 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c6100, element=(string)queue1, src=(string)src, time=(guint64)107466106, ts=(guint64)10633442255
0:00:10.678256034 [331m38502[00m      0x22bcf00 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x28072d0, element=(string)primary-inference, src=(string)src, time=(guint64)44764304, ts=(guint64)10678206559;
0:00:10.679663686 [331m38502[00m      0x22bcea0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c6400, element=(string)queue2, src=(string)src, time=(guint64)1395839, ts=(guint64)10679602398;
0:00:10.680110671 [331m38502[00m      0x22bcea0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x281a8d0, element=(string)nvtiler, src=(string)src, time=(guint64)471353, ts=(guint64)10680073751;
0:00:10.680277099 [331m38502[00m      0x22bce40 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c6700, element=(string)queue3, src=(string)src, time=(guint64)153828, ts=(guint64)10680227579;
0:00:10.680869243 [331m38502[00m      0x22bce40 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x280b0d0, element=(string)convertor, src=(string)src, time=(guint64)584780, ts=(guint64)10680812359;
0:00:10.681020478 [331m38502[00m      0x22bcde0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c6a00, element=(string)queue4, src=(string)src, time=(guint64)167112, ts=(guint64)10680979471;
0:00:10.682192855 [331m38502[00m      0x22bcde0 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x2802d70, element=(string)onscreendisplay, src=(string)src, time=(guint64)1184797, ts=(guint64)10682164268;
0:00:10.682352493 [331m38502[00m      0x22bcd80 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m element-latency, element-id=(string)0x22c6d00, element=(string)queue5, src=(string)src, time=(guint64)70182, ts=(guint64)10682234450;

0:00:10.682292093 [331m38502[00m      0x22bcd80 [37mTRACE  [00m [00;34m          GST_TRACER :0::[00m latency, src-element-id=(string)0x7efedc023480, src-element=(string)udpsrc0, src=(string)src, sink-element-id=(string)0x28f01f0, sink-element=(string)nvvideo-renderer, sink=(string)sink, time=(guint64)317531202, ts=(guint64)10682234450;

# %%
# RTSP video stream
import re
from collections import defaultdict
import matplotlib.pyplot as plt


def analyze_time_values_by_element(log_filename):
    with open(log_filename, 'r') as file:
        lines = file.readlines()

    time_values_by_element = defaultdict(list)

    for line in lines:
        # Use a regular expression to find the "element" and "time" attributes and their values
        element_match = re.search(r"element=\(string\)([^,]+),", line)
        time_match = re.search(r"time=\(guint64\)(\d+),", line)

        if element_match and time_match :
            element_value = element_match.group(1)
            time_value_ns = int(time_match.group(1))
            time_value_ms = time_value_ns / 1e6  # Convert nanoseconds to milliseconds
            time_values_by_element[element_value].append(time_value_ms)

            # Break the loop if the maximum samples is reached for the first element
            if len(time_values_by_element[element_value]) == 1000:
                    break

    # Calculate statistics for each element
    element_statistics = {element: {"mean": sum(times) / len(times), "count": len(times)} for element, times in time_values_by_element.items()}

    return element_statistics, time_values_by_element

# Example usage
log_filename = 'base.log'
element_statistics, time_values_by_element = analyze_time_values_by_element(log_filename)

# Print the element-wise statistics
for element, stats in element_statistics.items():
    if element!='udpsrc0':
        print(f"Element: {element}, Mean Time: {stats['mean']}, Count: {stats['count']}")
    else:
        print(f"Pipeline: {element}, Mean Time: {stats['mean']}, Count: {stats['count']}")

# Plot the time values for each element
element_filter = ["primary-inference", "queue1","nvv4l2decoder0","udpsrc0"]
for element, times in time_values_by_element.items():
    if element in element_filter:
        plt.plot(times, label=element)

plt.xlabel('Sample Index')
plt.ylabel('Time')
plt.title('Time values for each element')
plt.legend()
plt.show()
# Out:
# Element: rtpsession0, Mean Time: 0.056091, Count: 1
# Element: rtpstorage0, Mean Time: 0.082243, Count: 1
# Element: rtpssrcdemux0, Mean Time: 0.048579, Count: 1
# Element: rtpjitterbuffer0, Mean Time: 0.248936, Count: 1
# Element: rtpptdemux0, Mean Time: 0.041973, Count: 1
# Element: typefind, Mean Time: 0.04728, Count: 1
# Element: rtph264depay0, Mean Time: 0.066438, Count: 1
# Element: h264parse0, Mean Time: 0.119875, Count: 1
# Element: capsfilter0, Mean Time: 0.040679, Count: 1
# Element: nvv4l2decoder0, Mean Time: 160.311492, Count: 1
# Element: Stream-muxer, Mean Time: 0.209315, Count: 1
# Element: queue1, Mean Time: 107.466106, Count: 1
# Element: primary-inference, Mean Time: 44.764304, Count: 1
# Element: queue2, Mean Time: 1.395839, Count: 1
# Element: nvtiler, Mean Time: 0.471353, Count: 1
# Element: queue3, Mean Time: 0.153828, Count: 1
# Element: convertor, Mean Time: 0.58478, Count: 1
# Element: queue4, Mean Time: 0.167112, Count: 1
# ...

# %%
time_values_by_element
data = time_values_by_element

# 提取数据
elements = list(data.keys())
times = [value[0] for value in data.values()]

# 创建柱状图
plt.figure(figsize=(10, 6))
plt.bar(elements, times, color='blue')
plt.xlabel('Elements')
plt.ylabel('Time (milliseconds)')
plt.title('Processing Time for Each Element')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# 显示图表
plt.show()

# %%
# 计算总时间
data_ms = time_values_by_element
# 提取数据
elements = list(data_ms.keys())
times_ms = [value[0] for value in data_ms.values()]

# 计算总时间
total_time = sum(times_ms)

# 计算每个元素的百分比
percentages = [(time / total_time) * 100 for time in times_ms]

# 创建饼状图
plt.figure(figsize=(10, 6))
plt.pie(percentages, labels=elements, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Processing Time for Each Element')
plt.axis('equal')  # 使饼状图保持圆形
plt.tight_layout()

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt


# 提取数据
elements = list(data_ms.keys())
times_ms = [value[0] for value in data_ms.values()]

# 计算总时间
total_time = sum(times_ms)

# 计算每个元素的百分比
percentages = [(time / total_time) * 100 for time in times_ms]

# 将比例低于5%的元素合并为'others'
threshold = 5.0
elements_combined = []
percentages_combined = []

for element, percent in zip(elements, percentages):
    if percent < threshold:
        # 将比例低于5%的元素时间累加到 'others' 元素
        if 'others' not in elements_combined:
            elements_combined.append('others')
            percentages_combined.append(0)
        percentages_combined[elements_combined.index('others')] += percent
    else:
        elements_combined.append(element)
        percentages_combined.append(percent)

# 创建饼状图
plt.figure(figsize=(10, 6))
plt.pie(percentages_combined, labels=elements_combined, autopct='%1.1f%%', startangle=90)
plt.title(f'Processing Time for Each Element')
plt.axis('equal')  # 使饼状图保持圆形
plt.tight_layout()

# 显示图表
plt.show()
